# %%
#3.1.1

masses = [1.9891e+30, 1.8986e+27, 
          5.6846e+26, 1.0243e+26, 8.6810e+25,
          5.9736e+24, 4.8685e+24, 6.4185e+23, 
          3.3022e+23, 7.349e+22, 1.25e22]

masses.sort()
ltmoon = []

for x in range(0, len(masses)):
    if masses[x] <= 7.349e+22:
        ltmoon.append(masses[x])

masses = set(masses)
ltmoon = set(ltmoon)

masses = masses.difference(ltmoon)
masses = list(masses)

print(masses)
# Out:
# [1.8986e+27, 1.9891e+30, 3.3022e+23, 1.0243e+26, 5.9736e+24, 4.8685e+24, 5.6846e+26, 6.4185e+23, 8.681e+25]

# %%
#3.1.2

masses = [1.9891e+30, 1.8986e+27, 
          5.6846e+26, 1.0243e+26, 8.6810e+25,
          5.9736e+24, 4.8685e+24, 6.4185e+23, 
          3.3022e+23, 7.349e+22, 1.25e22]

masses5 = masses[:-6:-1]
print(masses5)

#3.1.3

avgmass = sum(masses5) / len(masses5)
print("Average mass in new list is:", avgmass)
# Out:
# [1.25e+22, 7.349e+22, 3.3022e+23, 6.4185e+23, 4.8685e+24]
# Average mass in new list is: 1.1853119999999999e+24

# %%
#3.2

masses = [1.9891e+30, 1.8986e+27, 5.6846e+26, 
          1.0243e+26, 8.6810e+25, 5.9736e+24, 
          4.8685e+24, 6.4185e+23, 3.3022e+23, 
          7.349e+22, 1.25e22]
radii  = [696340, 71492, 60268, 24764, 
          25559, 6378.1, 6051.8, 3396.2, 
          2439.7, 1738.1, 1195]
names  = ['Sun', 'Jupiter', 'Saturn', 'Neptune', 
          'Uranus', 'Earth', 'Venus', 'Mars', 
          'Mercury', 'Moon', 'Pluto']

esc = {}

for x in range(0, len(masses)):
    esc[names[0]]
